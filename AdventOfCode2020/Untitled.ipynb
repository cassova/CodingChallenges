# %%
# %%time
ls = [9,12,1,4,17,0,18]
ls.reverse()

for i in range(len(ls)-1,2020):
    try:
        idx = ls[1:].index(ls[0])+1
    except:
        idx = -1
        
    if idx > 0:
        ls.insert(0,idx)
    else:
        ls.insert(0,0)

ls.reverse()
ls
# Out:
# Wall time: 8.95 ms
# [9,
#  12,
#  1,
#  4,
#  17,
#  0,
#  18,
#  0,
#  2,
#  0,
#  2,
#  2,
#  1,
#  10,
#  0,
#  5,
#  0,
#  2,
#  6,
#  0,
#  3,
#  0,
#  2,
#  5,
#  8,
#  0,
#  4,
#  23,
#  0,
#  3,
#  9,
#  30,
#  0,
#  4,
#  7,
#  0,
#  3,
#  7,
#  3,
#  2,
#  17,
#  36,
#  0,
#  7,
#  6,
#  26,
#  0,
#  4,
#  14,
#  0,
#  3,
#  12,
#  50,
#  0,
#  4,
#  7,
#  12,
#  5,
#  34,
#  0,
#  6,
#  16,
#  0,
#  3,
#  13,
#  0,
#  3,
#  3,
#  1,
#  56,
#  0,
#  5,
#  14,
#  24,
#  0,
#  4,
#  21,
#  0,
#  3,
#  11,
#  0,
#  3,
#  3,
#  1,
#  15,
#  0,
#  5,
#  15,
#  3,
#  6,
#  29,
#  0,
#  6,
#  3,
#  5,
#  8,
#  71,
#  0,
#  6,
#  6,
#  1,
#  17,
#  61,
#  0,
#  6,
#  5,
#  11,
#  27,
#  0,
#  5,
#  4,
#  35,
#  0,
#  4,
#  3,
#  21,
#  39,
#  0,
#  5,
#  9,
#  89,
#  0,
#  4,
#  9,
#  4,
#  2,
#  86,
#  0,
#  6,
#  24,
#  56,
#  61,
#  29,
#  42,
#  0,
#  7,
#  80,
#  0,
#  3,
#  24,
#  10,
#  127,
#  0,
#  5,
#  25,
#  0,
#  3,
#  8,
#  52,
#  0,
#  4,
#  26,
#  106,
#  0,
#  4,
# ...
